# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
#定义Mydataset继承自Dataset,并重写__getitem__和__len__
class Mydataset(Dataset):
    def __init__(self, num):
        super(Mydataset, self).__init__()
        self.num = num #生成多少个点（多少个数据）

        def linear_f(x):
            y = 5 * x + np.sin(x) * x + np.random.normal(
                0, scale=1, size=x.size) # y = 5*x + x*sin(x) + noise
            print(type(x))
            print(type(y))
            return y

        self.x_train = np.linspace(0, 50, num=self.num) #从0-50生成num多个点
        print(type(self.x_train))
        print(self.x_train.size)
        self.y_train = linear_f(self.x_train)
        self.x_train = torch.Tensor(self.x_train)#转化为张量
        self.y_train = torch.Tensor(self.y_train)
        print(type(self.x_train))
    # indexing
    def __getitem__(self, index):
        print(self.x_train[index])
        return self.x_train[index], self.y_train[index]
    #返回数据集大小，应该是（x_transpose,y_transpose）大小即num*2，这里我直接返回了num
    def __len__(self):
        print(self.num)
        return self.num
if __name__ == "__main__":
    num = 30
    myset = Mydataset(num=num)
    myloader = DataLoader(dataset=myset, batch_size=1, shuffle=False)
    for data in myloader:
        print(data)
# Out:
# <class 'numpy.ndarray'>
# 30
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'torch.Tensor'>
# 30
# tensor(0.)
# [tensor([0.]), tensor([-0.1128])]
# tensor(1.7241)
# [tensor([1.7241]), tensor([9.6852])]
# tensor(3.4483)
# [tensor([3.4483]), tensor([15.7247])]
# tensor(5.1724)
# [tensor([5.1724]), tensor([21.3416])]
# tensor(6.8966)
# [tensor([6.8966]), tensor([37.1210])]
# tensor(8.6207)
# [tensor([8.6207]), tensor([47.5543])]
# tensor(10.3448)
# [tensor([10.3448]), tensor([41.7009])]
# tensor(12.0690)
# [tensor([12.0690]), tensor([55.4386])]
# tensor(13.7931)
# [tensor([13.7931]), tensor([82.8907])]
# tensor(15.5172)
# [tensor([15.5172]), tensor([79.7880])]
# tensor(17.2414)
# [tensor([17.2414]), tensor([68.7821])]
# tensor(18.9655)
# [tensor([18.9655]), tensor([96.1412])]
# tensor(20.6897)
# [tensor([20.6897]), tensor([121.3660])]
# tensor(22.4138)
# [tensor([22.4138]), tensor([103.5641])]
# tensor(24.1379)
# [tensor([24.1379]), tensor([101.8763])]
# tensor(25.8621)
# [tensor([25.8621]), tensor([146.3654])]
# tensor(27.5862)
# [tensor([27.5862]), tensor([155.1679])]
# tensor(29.3103)
# [tensor([29.3103]), tensor([120.5854])]
# tensor(31.0345)
# [tensor([31.0345]), tensor([141.9998])]
# tensor(32.7586)
# [tensor([32.7586]), tensor([196.1514])]
# tensor(34.4828)
# [tensor([34.4828]), tensor([174.8178])]
# tensor(36.2069)
# [tensor([36.2069]), tensor([144.5283])]
# tensor(37.9310)
# [tensor([37.9310]), tensor([198.8382])]
# tensor(39.6552)
# [tensor([39.6552]), tensor([235.0179])]
# tensor(41.3793)
# [tensor([41.3793]), tensor([185.2832])]
# tensor(43.1034)
# [tensor([43.1034]), tensor([183.4406])]
# tensor(44.8276)
# [tensor([44.8276]), tensor([258.7051])]
# tensor(46.5517)
# [tensor([46.5517]), tensor([257.9085])]
# tensor(48.2759)
# [tensor([48.2759]), tensor([197.2202])]
# tensor(50.)
# [tensor([50.]), tensor([236.4485])]

# %%
from torch.utils.data import DataLoader,TensorDataset
import numpy as np
import torch


def linear_f(x):
    y = 5 * x + np.sin(x) * x + np.random.normal(
        0, scale=1, size=x.size) # y = 5*x + x*sin(x) + noise
    return y


if __name__ == "__main__":
    num = 30
    x_train = np.linspace(0, 50, num=num) #从0-50生成num多个点
    y_train = linear_f(x_train)
    x_train = torch.Tensor(x_train)#转化为张量
    y_train = torch.Tensor(y_train)
    myset = TensorDataset(x_train,y_train)
    myloader = DataLoader(dataset=myset, batch_size=1, shuffle=False)
    for data in myloader:
        print(data)
# Out:
# [tensor([0.]), tensor([0.1530])]
# [tensor([1.7241]), tensor([10.5261])]
# [tensor([3.4483]), tensor([14.0848])]
# [tensor([5.1724]), tensor([22.2758])]
# [tensor([6.8966]), tensor([39.2612])]
# [tensor([8.6207]), tensor([48.6972])]
# [tensor([10.3448]), tensor([44.4339])]
# [tensor([12.0690]), tensor([54.1740])]
# [tensor([13.7931]), tensor([81.5650])]
# [tensor([15.5172]), tensor([80.6523])]
# [tensor([17.2414]), tensor([69.8322])]
# [tensor([18.9655]), tensor([97.7354])]
# [tensor([20.6897]), tensor([121.9349])]
# [tensor([22.4138]), tensor([102.1847])]
# [tensor([24.1379]), tensor([100.1009])]
# [tensor([25.8621]), tensor([145.9930])]
# [tensor([27.5862]), tensor([156.2715])]
# [tensor([29.3103]), tensor([121.0780])]
# [tensor([31.0345]), tensor([146.1943])]
# [tensor([32.7586]), tensor([195.5150])]
# [tensor([34.4828]), tensor([174.6441])]
# [tensor([36.2069]), tensor([144.5325])]
# [tensor([37.9310]), tensor([197.7619])]
# [tensor([39.6552]), tensor([233.9137])]
# [tensor([41.3793]), tensor([185.9722])]
# [tensor([43.1034]), tensor([182.9665])]
# [tensor([44.8276]), tensor([258.7413])]
# [tensor([46.5517]), tensor([257.4864])]
# [tensor([48.2759]), tensor([198.1726])]
# [tensor([50.]), tensor([236.9764])]
